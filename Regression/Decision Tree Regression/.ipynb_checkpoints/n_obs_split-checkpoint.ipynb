# %% [markdown]
# ### hyper-parameter no. - 4
# ### the number of observations initially considered when trying to figure out the best possible split at each node.
# #### Let's call this hyper parameter n_obs_split for ease of reference in the future. I'd like to find out how does the change in this parameter affect the model.

# %%
# Let's consider a simple dummy dataset (bell curve) for the ease of understanding.
import random as r
import math
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# <font size ="5"> $$ f(x) = \frac{1}{\sigma \sqrt{2\pi}}e^{\frac{-(x-\mu)^2}{2\sigma}} $$ </font>

# %%
def bell_function(x, mu, sigma):
    y_s = []
    for i in x:
        y_s.append( (1/sigma*math.sqrt(2*math.pi) * math.e**(-(i-mu)**2/(2*sigma))) * 100 )
    return y_s

def scrappy_2D_bell(mu,sigma,size):
    x = np.linspace(mu-sigma,mu+sigma,size)
    y = bell_function(x, mu, sigma)
    return x,y

# %%
x,y = scrappy_2D_bell(20,6,16)

# %%
df = pd.read_csv('50_Startups.csv', usecols=['R&D Spend','Profit'])

# %%
plt.scatter(df['R&D Spend'],df['Profit'])
plt.show()

# %%
# dataset ready
# Now lets create a function that returns the outputs  X vs SSR graph & values as was seen in Josh's video above. This 
# will calculate the SSR based on the n_obs_split value.

# %%
class analyze_n_obs_split:
    
    def __init__(self, X,Y,n_arrs):
        self.X = X
        self.Y = Y
        self.n_arrs = n_arrs
        
    
    def get_SSRs(self):        
        self.data = {f"n={x}":[] for x in self.n_arrs}
        
        z = list(zip(self.X, self.Y))
        z = sorted(z)
        
        for n in self.n_arrs:
            slider_start = 0                                               
            slider_end = n
            while (slider_end!=len(z)+1):
                SSR = 0                                                    # init SSR 
                slider = z[slider_start : slider_end]                      # the observations under consideration for split
                split = sum([x[0] for x in slider])/len(slider)            # the split
                zleft = [left for left in z if left[0]<=split]             # the left set of datapoints
                zright = [right for right in z if right[0]>split]          # the right set of datapoints
                
                left_y_avg = sum([x[1] for x in zleft])/len(zleft)         # the avg Y of left set of dp
                right_y_avg = sum([x[1] for x in zright])/len(zright)      # the avg Y of right set of dp
                
                # calculating SSR from prediction
                for x in zleft:
                    SSR += (x[1] - left_y_avg)**2
                for y in zright:
                    SSR += (y[1] - right_y_avg)**2
                
                #append data
                self.data[f"n={n}"].append([split, SSR])
                
                slider_start += 1
                slider_end += 1            
        
    
    def record_data(self):
        upper_column_names = [f"n={x}" for x in self.n_arrs]                  # upper level column names
        mux = pd.MultiIndex.from_product([upper_column_names, ['X','SSR']])     # creating multi-index
        
        dfs = []
        for x in self.data:
            dfs.append(pd.DataFrame(self.data[f"{x}"]))                      # creating & storing a df for each n
        
        self.df = pd.concat(dfs, axis=1)                                     # merging all dfs
        self.df.columns = mux                                                # naming of columns
        
        
    def run_analysis(self):
        self.get_SSRs()
        self.record_data()
        
    def best_split(self):
        min_SSR = 99999999999999999999
        which_point = None
        for x in self.data:
            for data in analyser.data[x]:
                if data[1]<min_SSR:
                    min_SSR = data[1]
                    which_point = data 
        return "[X, SSR] :", which_point

# %%
analyser = analyze_n_obs_split(df['R&D Spend'], df['Profit'], [3,7,13])

# %%
analyser.run_analysis()

# 39  121273.546667  4.086347e+10  128959.781429  4.285354e+10            NaN
# 40  124725.176667  4.285354e+10  132449.662857  4.804031e+10            NaN
# 41  128503.303333  4.285354e+10  137149.518571  5.014007e+10            NaN
# 42  132263.496667  4.804031e+10  142758.492857  5.349815e+10            NaN
# 43  136199.900000  5.014007e+10  147765.788571  5.933790e+10            NaN
# 44  140365.070000  5.014007e+10            NaN           NaN            NaN
# 45  146640.420000  5.933790e+10            NaN           NaN            NaN
# 46  153470.540000  6.626672e+10            NaN           NaN            NaN
# 47  160462.803333  6.626672e+10            NaN           NaN            NaN
#
#
#              SSR
# 0   5.005680e+10
# 1   5.005680e+10
# 2   4.637072e+10
# 3   4.393178e+10
# 4   3.981650e+10
# 5   3.981650e+10
# 6   3.790137e+10
# 7   3.790137e+10
# 8   3.698342e+10
# 9   3.631495e+10
# 10  3.631495e+10
# 11  3.631495e+10
# 12  3.574249e+10
# 13  3.574249e+10
# 14  3.459888e+10
# 15  3.375192e+10
# 16  3.205513e+10
# 17  3.205513e+10
# 18  3.205513e+10
# 19  3.126397e+10
# 20  3.097944e+10
# 21  3.037099e+10
# 22  2.953486e+10
# 23  2.953486e+10
# 24  2.953486e+10
# 25  2.953486e+10
# 26  2.982998e+10
# 27  3.160148e+10
# 28  3.376468e+10
# 29  3.376468e+10
# 30  3.834826e+10
# 31  3.834826e+10
# 32  3.834826e+10
# 33  3.827437e+10
# 34  3.827437e+10
# 35  4.285354e+10
# 36  4.285354e+10
# 37  4.804031e+10
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# 44           NaN
# 45           NaN
# 46           NaN
# 47           NaN

# %%
# %matplotlib notebook

# %%
fig, axs = plt.subplots(1,3, figsize=(15,3))

axs[0].scatter(analyser.df.loc[:, ('n=3','X')], analyser.df.loc[:, ('n=3','SSR')], c='orange')
axs[0].plot([analyser.X.min(),analyser.X.max()],[analyser.best_split()[1][1], analyser.best_split()[1][1]], c='red')
axs[0].set_xlabel('X', fontsize=13)
axs[0].set_ylabel('SSR', fontsize=13)
axs[0].set_title('n=3', fontsize=20)

axs[1].scatter(analyser.df.loc[:, ('n=7','X')], analyser.df.loc[:, ('n=7','SSR')], c='orange')
axs[1].plot([analyser.X.min(),analyser.X.max()],[analyser.best_split()[1][1], analyser.best_split()[1][1]], c='red')
axs[1].set_xlabel('X', fontsize=13)
axs[1].set_title('n=7', fontsize=20)


axs[2].scatter(analyser.df.loc[:, ('n=13','X')], analyser.df.loc[:, ('n=13','SSR')], c='orange')
axs[2].plot([analyser.X.min(),analyser.X.max()],[analyser.best_split()[1][1], analyser.best_split()[1][1]], c='red')
axs[2].set_xlabel('X', fontsize=13)
axs[2].set_title('n=13', fontsize=20)
# Out:
# <img src="data:image/png;base64,..." width="1499.5555555555557">
# Text(0.5, 1.0, 'n=13')

# %%
analyser.best_split()
# Out:
# ('[X, SSR] :', [77103.65999999999, 29361540434.066177])

# %%
# To be continued...
